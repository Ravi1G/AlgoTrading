# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pipeline
import pandas as pd

# %%
MY_KEY = 'DGXTHCQ81XKZLWGX'

# %%
df = pd.read_csv('https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=dfdf&apikey={}&datatype=csv'.format(MY_KEY))

# %%
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.techindicators import TechIndicators
from alpha_vantage.sectorperformance import SectorPerformances
from alpha_vantage.cryptocurrencies import CryptoCurrencies
import matplotlib
import matplotlib.pyplot as plt
import os

# %%
ts = TimeSeries(key=os.environ['AV_API_KEY'], output_format='pandas')

# %%
meta_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-f460a3fbd13b> in <module>
# ----> 1 meta_data
#
# NameError: name 'meta_data' is not defined

# %%
data, meta_data = ts.get_batch_stock_quotes(symbols=('MSFT', 'FB', 'AAPL'))

# %%
data, met= ts.get_daily('ddddd', outputsize='full')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-97d203af0f8f> in <module>
# ----> 1 data, met= ts.get_daily('ddddd', outputsize='full')
#
# ~\Anaconda3\envs\labx\lib\site-packages\alpha_vantage\alphavantage.py in _format_wrapper(self, *args, **kwargs)
#     176             if 'json' in self.output_format.lower() or 'pandas' \
#     177                     in self.output_format.lower():
# --> 178                 data = call_response[data_key]
#     179                 if meta_data_key is not None:
#     180                     meta_data = call_response[meta_data_key]
#
# KeyError: 'Time Series (Daily)'

# %%
data
# Out:
#             1. open   2. high    3. low  4. close   5. volume
# date
# 1998-01-02  129.630  131.5000  129.5000    131.13   4968500.0
# 1998-01-05  131.250  133.6300  127.8700    130.38  10047200.0
# 1998-01-06  129.750  133.0000  129.2500    131.13   8479300.0
# 1998-01-07  129.880  131.1900  127.5000    129.56   7686600.0
# 1998-01-08  128.630  132.1300  127.5000    130.50   9702400.0
# 1998-01-09  130.060  131.5000  125.8700    127.00  10941800.0
# 1998-01-12  124.620  130.0000  124.3700    129.50   9799200.0
# 1998-01-13  129.500  132.2500  128.1300    132.13   8368200.0
# 1998-01-14  132.130  132.5000  129.2500    131.13   6846800.0
# 1998-01-15  130.380  133.0000  129.8800    132.31   6327800.0
# 1998-01-16  132.380  135.3800  132.3100    135.25   9117900.0
# 1998-01-20  134.130  138.0000  134.0000    137.81   8119500.0
# 1998-01-21  137.250  138.4400  135.6300    137.00  10695900.0
# 1998-01-22  135.560  139.8800  135.3100    138.63  19892400.0
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import io

# %%
content = requests.get('https://www.ishares.com/us/products/239726/ishares-core-sp-500-etf/1467271812596.ajax?fileType=csv&fileName=IVV_holdings&dataType=fund&asOfDate=20190329')

# %%
business_month_end
# Out:
# Timestamp('1993-11-30 00:00:00')

# %%
business_month_end = pd.to_datetime('1993-12-17') + pd.offsets.BMonthEnd(-1)

# %%
business_month_end.date().strftime("%Y%m%d")
# Out:
# '19931130'

# %%
df = pd.read_csv(io.StringIO(content.text), skiprows=10)

# %%
df['Ticker'].values
# Out:
# array(['MSFT', 'AAPL', 'AMZN', 'FB', 'BRKB', 'JNJ', 'GOOG', 'GOOGL',
#        'XOM', 'JPM', 'V', 'PG', 'BAC', 'VZ', 'INTC', 'CSCO', 'UNH', 'PFE',
#        'CVX', 'T', 'HD', 'MRK', 'MA', 'BA', 'WFC', 'DIS', 'CMCSA', 'KO',
#        'PEP', 'NFLX', 'C', 'MCD', 'ABT', 'WMT', 'PM', 'ORCL', 'ADBE',
#        'IBM', 'MDT', 'PYPL', 'CRM', 'UNP', 'DWDP', 'MMM', 'AVGO', 'ABBV',
#        'AMGN', 'HON', 'ACN', 'LLY', 'TMO', 'NVDA', 'MO', 'COST', 'NKE',
#        'UTX', 'TXN', 'LIN', 'NEE', 'SBUX', 'LOW', 'GE', 'AMT', 'GILD',
#        'DHR', 'BKNG', 'CAT', 'BMY', 'UPS', 'COP', 'AXP', 'LMT', 'ANTM',
#        'USB', 'MDLZ', 'CVS', 'ADP', 'QCOM', 'INTU', 'BDX', 'CELG', 'TJX',
#        'GS', 'DUK', 'ISRG', 'CB', 'D', 'CI', 'SYK', 'SLB', 'CHTR', 'CL',
#        'CME', 'CSX', 'SPG', 'PNC', 'EOG', 'MS', 'SO', 'BSX', 'CCI',
#        'SPGI', 'BLK', 'RTN', 'DE', 'WBA', 'SCHW', 'NSC', 'OXY', 'GM',
#        'EXC', 'ZTS', 'MMC', 'VRTX', 'BIIB', 'MU', 'GD', 'NOC', 'AGN',
# ...
